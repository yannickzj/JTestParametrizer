# %%
from pandas import DataFrame, read_csv
import pandas as pd

# %%
df = pd.read_excel('jfreechart-1.0.10-ccfinder.xls')

# %%
df
# Out:
#       Clone Group ID Source Folder                                  Package  \
# 0                 30         tests                    org.jfree.chart.junit
# 1                 30         tests               org.jfree.chart.plot.junit
# 2                 31         tests                org.jfree.data.time.junit
# 3                 31         tests  org.jfree.chart.renderer.category.junit
# 4                 32         tests        org.jfree.chart.annotations.junit
# 5                 32         tests          org.jfree.data.statistics.junit
# 6                 32         tests              org.jfree.chart.block.junit
# 7                 33         tests               org.jfree.chart.urls.junit
# 8                 33         tests           org.jfree.chart.renderer.junit
# 9                 34         tests               org.jfree.data.gantt.junit
# 10                34         tests            org.jfree.data.category.junit
# ...
